# %%
from custom.clip_ebc_onnx import ClipEBCOnnx
model = ClipEBCOnnx(onnx_model_path="clip_ebc_model.onnx")
count1 = model.predict("assets/289.jpg")
count1
# Out:
# ONNX 모델 로드 중: clip_ebc_model.onnx
# 입력 이름: input, 형태: ['batch_size', 3, 224, 224]
# 출력 이름: output, 형태: ['batch_size', 1, 'ReduceSumoutput_dim_2', 'ReduceSumoutput_dim_3']
# 실행 제공자: ['CPUExecutionProvider']
# 221.51328

# %%
tmp , tmp2= model.visualize_density_map(save=True)
tmp2
# Out:
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:372: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:372: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:372: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:372: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:372: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# 이미지 저장 완료: crowd_density_20250313_094606.png
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:375: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:375: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:375: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:375: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:375: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
tmp , tmp2 = model.visualize_dots(save=True)
tmp2
# Out:
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:436: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:436: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:436: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:436: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:436: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   plt.savefig(save_path, bbox_inches='tight', pad_inches=0, dpi=200)
# 이미지 저장 완료: crowd_dots_20250313_094613.png
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:440: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:440: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:440: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:440: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# /home/jungseoik/data/PR/CLIP_EBC/CLIP_EBC_ONNX/custom/clip_ebc_onnx.py:440: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.draw()
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50696 (\N{HANGUL SYLLABLE YE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 52769 (\N{HANGUL SYLLABLE CEUG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 51064 (\N{HANGUL SYLLABLE IN}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 50896 (\N{HANGUL SYLLABLE WEON}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/jungseoik/miniconda3/envs/ebc/lib/python3.12/site-packages/IPython/core/pylabtools.py:170: UserWarning: Glyph 47749 (\N{HANGUL SYLLABLE MYEONG}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)
